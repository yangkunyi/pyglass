# %%
from RDFProcessor import RDF_Processor
import numpy as np

# %%
raw_data = np.load("Test diff 128x128x0,036A-1.npy")

# %%
RDF_Processor.set_image(raw_data)
RDF_Processor.set_element_data([{"atomicNumber": 6, "percentage": 100}])

# %%
RDF_Processor.set_scattering_factor_function()

# %%
RDF_Processor.set_parameters(
    q_per_pixel=0.036,
    start_index=6,
    end_index=128,
    fit_threshold=0.8,
    r_min=0.01,
    r_max=6
)

# %%
result =RDF_Processor.process()

# %%
import matplotlib.pyplot as plt
plt.plot(result['pdf'])
